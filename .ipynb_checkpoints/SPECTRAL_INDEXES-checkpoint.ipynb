# %% [markdown]
# ***Spectral Indexes Computation***

# %%
#Importing
import os
import sys
sys.path.insert(1,'./src')
import numpy as np
import matplotlib.pyplot as plt
from find_nearest import find_nearest
plt.style.use('bmh')
import rasterio as rio
from img_list import prs_list
import math
from read_funcs import compute_index

# %%
#Parameter Initialization
path_l2d = "../DATABASE/"
aerial_path="../DATABASE/aerial/"
name='Gad161022'
name_img_prs=prs_list[name]
tstart_prs=prs_list[name][0]
tend_prs=prs_list[name][1]
filename=path_l2d+'PRS_L2D_STD_'+tstart_prs+'_'+tend_prs+'_0001'
print(tstart_prs)
prisma=False
save=True
#veg: vegetation index name, set this parameter with one of the following:  CLRE, GNDVI, NBRI, NDREI, NDVI, NRVI, REIP and SLAVI. 
veg='SLAVI'
# Out:
# 20221016102331

# %%
#import reflectance
if prisma:
    src = rio.open(path_l2d+filename+'_reflectance.tif')
    reflectance=src.read()
    src.close()
    reflectance=np.moveaxis(reflectance,0,2)    
    wvl=np.load(path_l2d+'/'+name+'_wl.npy')
else:
    src_aerial = rio.open(path_l2d+'aerial/'+'Gadertal_area5_EPSG4326.tif')
    raw=src_aerial.read()
    src_aerial.close()
    raw=np.moveaxis(raw,0,2)
    reflectance=raw*0.0001 #scale to reflectance
    reflectance=np.where(reflectance>1,math.nan,reflectance)
    plt.hist(reflectance.ravel(),bins=50)
    wvl=np.load(aerial_path+'aerial_wl.npy')

# %%
#count percentage of pixels marked as dead trees in validation (to set threshold)
src = rio.open(aerial_path+'Gad161022_area5_class.tif')
classification=src.read()
src.close()
classification=np.moveaxis(classification,0,2)
np.shape(classification)
plt.hist(classification.ravel(),bins=50)
print(np.max(classification.ravel()))
print(np.min(classification.ravel()))
total_pixels=np.where(classification!=10,1,0).sum()
print('total: ' + str(total_pixels))
dead_pixels=np.where((classification==1),1,0).sum()
print('dead trees pixels: '+ str(dead_pixels))
percentage=round((dead_pixels*100)/total_pixels)
print("percentage of trees' pixels: "+str(percentage)+'%')
# Out:
# 6
# 0
# total: 236000
# dead trees pixels: 9416
# percentage of trees' pixels: 4%

# %%
#import aerial trees mask and mask reflectance cube
trees_mask=np.load(aerial_path+name+'_trees_mask.npy')
trees_mask=np.where(trees_mask==1,trees_mask,np.nan)
trees_ref=np.zeros((np.shape(reflectance)))
for b in range(np.shape(reflectance)[2]):
    trees_ref[:,:,b]=np.multiply(reflectance[:,:,b],trees_mask)

# %%
#compute vegetation index
veg_map=compute_index(trees_ref,veg,wvl)
plt.figure()
plt.hist(veg_map.ravel(),bins=50) 
plt.title(veg,fontweight='bold',fontsize=20)
plt.figure(figsize=(30,8))
plt.subplot(1,3,1)
plt.imshow(veg_map)
plt.title(veg,fontweight='bold',fontsize=20)
plt.colorbar()
if save:
    np.save(aerial_path+name+'_'+veg,veg_map)
dead_trees_mask=np.load(aerial_path+name+'_dead_trees_mask.npy')
dead=[]
dead=np.where(dead_trees_mask==1,veg_map,np.nan)
plt.subplot(1,3,2)
plt.imshow(dead)
plt.title(veg+' dead trees',fontweight='bold',fontsize=20)
plt.colorbar()

healthy_trees_mask=np.load(aerial_path+name+'_healthy_trees_mask.npy')
healthy=[]
healthy=np.where(healthy_trees_mask==1,veg_map,np.nan)
plt.subplot(1,3,3)
plt.imshow(healthy)
plt.title(veg+' healthy trees',fontweight='bold',fontsize=20)
plt.colorbar()
# Out:
# /var/folders/_3/xbqrb2pn61xbq3bc9w9ss3ww0000gn/T/ipykernel_4277/3821942591.py:10: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()
# /var/folders/_3/xbqrb2pn61xbq3bc9w9ss3ww0000gn/T/ipykernel_4277/3821942591.py:19: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()
# /var/folders/_3/xbqrb2pn61xbq3bc9w9ss3ww0000gn/T/ipykernel_4277/3821942591.py:27: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar()

# %%
#statistics over random dead trees sample
index=np.isnan(dead.ravel())
index=[not item for item in index]
random_points=np.random.choice(dead.ravel()[index], size=1000)
plt.figure(figsize=(30,10))
plt.subplot(1,2,1)
plt.hist(random_points,bins=50)
plt.title(veg+' dead trees random sample histogram',fontweight='bold',fontsize=20)
plt.subplot(1,2,2)
plt.plot(range(np.shape(random_points)[0]),random_points)
plt.title(veg+' dead trees random sample plot',fontweight='bold',fontsize=20)
print('random sample '+veg+' mean dead trees: '+str(np.mean(random_points)))
print('random sample points '+veg+' std deviation dead trees: '+str(np.std(random_points)))
# Out:
# random sample REIP mean dead trees: 719.2455940563556
# random sample points REIP std deviation dead trees: 8.687166187249536

# %%
#statistics over random healthy trees sample
index=np.isnan(healthy.ravel())
index=[not item for item in index]
random_points=np.random.choice(healthy.ravel()[index], size=1000)
plt.figure(figsize=(30,10))
plt.subplot(1,2,1)
plt.hist(random_points,bins=50)
plt.title(veg+' healthy trees random sample histogram',fontweight='bold',fontsize=20)
plt.subplot(1,2,2)
plt.plot(range(np.shape(random_points)[0]),random_points)
plt.title(veg+' healthy trees random sample plot',fontweight='bold',fontsize=20)
print('random sample '+veg+' mean healthy trees: '+str(np.mean(random_points)))
print('random sample points '+veg+' std deviation healthy trees: '+str(np.std(random_points)))
# Out:
# random sample REIP mean healthy trees: 721.5823654952615
# random sample points REIP std deviation healthy trees: 2.1721367176968833

# %%
#binary classification
#veg_binary=np.where(veg_map>0.5,1,0)
#plt.figure(figsize=(10,10))
#plt.imshow(veg,cmap='binary')
